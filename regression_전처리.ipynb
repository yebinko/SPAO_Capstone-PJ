# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/Users/yebinko/Library/Mobile Documents/com~apple~CloudDocs/Documents/BA/Capstone/마스터파일/모델링기본데이터_편집1.xlsx')

# %%
df
# Out:
#      매장코드       매장명  유통경로  피팅룸수  영업일수  공급면적(평)      인원  오픈일수  매장진열캐파(구형고소미포함)  \
# 0    A9WP        강남   로드샵    21   365      506  37.325  2778          16252.0
# 1    ACKH     타임스퀘어   쇼핑몰    14   365      519  27.625  1334          10912.0
# 2    ABAG    스타필드고양  스타필드     9   365      257  25.075  2175           6454.0
# 3    AD0M    스타필드안성  스타필드    10   365      503  22.000  1030          11200.0
# 4    ACVZ  스타필드코엑스몰  스타필드    21   365      759  23.525  1166          14746.0
# ..    ...       ...   ...   ...   ...      ...     ...   ...              ...
# 96   ADV4      NC평촌  자사유통     4   357       91   3.000    97           2996.0
# 97   ADVL    스타필드명지  스타필드     3   365      104   5.975    88           3012.0
# 98   ADV5      NC야탑  자사유통     4   359       95   7.375    83           2474.0
# 99   ADW0   (NSC)영천   NSC     5   365      240   7.300    74           7086.0
# 100  ADVD      NC평택  자사유통     3   359       71   6.900    67           1872.0
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
mpl.rcParams['axes.unicode_minus'] = False

plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 11
plt.rcParams['figure.figsize'] = (10,8)

# %%
sns.heatmap(df.corr(), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
# Out:
# /var/folders/x2/c6gjhmqs6h5bl_d26ctv923h0000gn/T/ipykernel_30185/426618390.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['매장코드', '매장명', '유통경로', '피팅룸수', '영업일수', '공급면적(평)', '인원', '오픈일수',
#        '매장진열캐파(구형고소미포함)', '매장복잡도(구형고소포함)', '전체평균매출', '23년상반기평균매출', '23_2시즌매출',
#        '22_3시즌매출', '서비스 캐파'],
#       dtype='object')

# %%
df2 = df.drop(['전체평균매출', '23년상반기평균매출', '23_2시즌매출',
       '22_3시즌매출'], axis=1)

# %%
sns.heatmap(df2.corr(), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
# Out:
# /var/folders/x2/c6gjhmqs6h5bl_d26ctv923h0000gn/T/ipykernel_30185/1752223884.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
# <AxesSubplot:>

# %%
df_yrs = pd.read_csv('/Users/yebinko/Library/Mobile Documents/com~apple~CloudDocs/Documents/BA/Capstone/마스터파일/3개년매장재고_매장그룹.csv')

# %%
df.head(2)
# Out:
#    매장코드    매장명 유통경로  피팅룸수  영업일수  공급면적(평)      인원  오픈일수  매장진열캐파(구형고소미포함)  \
# 0  A9WP     강남  로드샵    21   365      506  37.325  2778          16252.0
# 1  ACKH  타임스퀘어  쇼핑몰    14   365      519  27.625  1334          10912.0
#
#    매장복잡도(구형고소포함)        전체평균매출   23년상반기평균매출      23_2시즌매출     22_3시즌매출  \
# 0      32.118577  1.085395e+09  982054153.3  9.913663e+08  936247524.0
# 1      22.566474  5.983327e+08  573914140.7  6.201701e+08  543277260.0
#
#       서비스 캐파
# 0  10.154052
# 1  14.081448

# %%
df_yrs.head()
# Out:
#    Year  Week  매장코드     매장명  기간판매량   잔여재고량  기간입고량  기간출고량
# 0  2021     1  A8LC  2001중계  152.0  1694.0    502     -1
# 1  2021     1  A8LH    NC일산  143.0  2229.0    439    -61
# 2  2021     1  A8LJ    NC고잔  105.0  1578.0     60    -10
# 3  2021     1  A8LL    NC덕천  139.0  1789.0    499      0
# 4  2021     1  A8LM    NC송파  145.0  2645.0    557    -11

# %%
df_merge = pd.merge(df_yrs, df2, how='inner', on='매장코드')

# %%
df_merge.head()
# Out:
#    Year  Week  매장코드   매장명_x  기간판매량   잔여재고량  기간입고량  기간출고량   매장명_y  유통경로  피팅룸수  \
# 0  2021     1  A8LC  2001중계  152.0  1694.0    502     -1  2001중계  자사유통     5
# 1  2021     2  A8LC  2001중계  141.0  2283.0    730      0  2001중계  자사유통     5
# 2  2021     3  A8LC  2001중계  207.0  2954.0    882     -4  2001중계  자사유통     5
# 3  2021     4  A8LC  2001중계  283.0  3765.0   1095     -1  2001중계  자사유통     5
# 4  2021     5  A8LC  2001중계  357.0  4074.0    666      0  2001중계  자사유통     5
#
#    영업일수  공급면적(평)     인원  오픈일수  매장진열캐파(구형고소미포함)  매장복잡도(구형고소포함)     서비스 캐파
# 0   360       95  6.575  5055           2802.0      29.494737  10.798479
# 1   360       95  6.575  5055           2802.0      29.494737  10.798479
# 2   360       95  6.575  5055           2802.0      29.494737  10.798479
# 3   360       95  6.575  5055           2802.0      29.494737  10.798479
# 4   360       95  6.575  5055           2802.0      29.494737  10.798479

# %%
df_merge.to_csv('리그레션용_매장그룹.csv', encoding='utf-8-sig')

# %%
sns.heatmap(df_merge.corr(), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
# Out:
# /var/folders/x2/c6gjhmqs6h5bl_d26ctv923h0000gn/T/ipykernel_30185/558194784.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_merge.corr(), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
# <AxesSubplot:>

# %%
df_po = pd.read_excel('/Users/yebinko/Library/Mobile Documents/com~apple~CloudDocs/Documents/BA/Capstone/마스터파일/모델링기본데이터_편집2_매출제외.xlsx')

# %%
df_merge2 = pd.merge(df_yrs, df_po, how='inner', on='매장코드')

# %%
sns.heatmap(df_merge2.corr(), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
# Out:
# /var/folders/x2/c6gjhmqs6h5bl_d26ctv923h0000gn/T/ipykernel_30185/1840732511.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_merge2.corr(), annot=True, annot_kws={"size": 8}, cmap='coolwarm')
# <AxesSubplot:>

# %%
df_merge2.to_csv('리그레션용_매장총파일.csv', encoding='utf-8-sig')

# %%
df_mean = pd.read_csv('/Users/yebinko/Library/Mobile Documents/com~apple~CloudDocs/Documents/BA/Capstone/마스터파일/3개년매장재고_매장그룹_평균.csv')

# %%
df_mean.head()
# Out:
#    Year  Week  매장코드     매장명          결판가  누적매장순수입고량      누적입고량      누적출고량  \
# 0  2021     1  A8LC  2001중계  39751.66667  39.847458  39.949153  -2.000000
# 1  2021     1  A8LH    NC일산  40243.03797  37.139241  38.512821 -11.666667
# 2  2021     1  A8LJ    NC고잔  40290.74074  36.703704  37.055556  -9.500000
# 3  2021     1  A8LL    NC덕천  40007.57576  38.651515  38.651515        NaN
# 4  2021     1  A8LM    NC송파  41521.42857  37.142857  37.297619  -6.500000
#
#        누적판매량     기간판매량      잔여재고량  누적판매율[입고량대비]  기간판매율[입고량대비]      기간입고량  \
# 0  11.526316  3.454545  28.233333     32.504156      9.345668  45.636364
# 1  10.071429  2.979167  28.215190     27.300955      7.674880  39.909091
# 2   8.977778  2.560976  29.222222     23.273986      7.311904  30.000000
# 3  16.933333  3.861111  27.106061     42.506489      8.502378  41.583333
# 4   7.786885  2.900000  31.488095     21.148514      7.438307  39.785714
#
#    기간출고량       소진율  판매주차수
# 0  -1.00  0.324748    1.0
# 1 -15.25  0.283816    1.0
# ...

# %%
df_merge3 = pd.merge(df_mean, df_po, how='inner', on='매장코드')

# %%
df_merge3.columns
# Out:
# Index(['Year', 'Week', '매장코드', '매장명_x', '결판가', '누적매장순수입고량', '누적입고량', '누적출고량',
#        '누적판매량', '기간판매량', '잔여재고량', '누적판매율[입고량대비]', '기간판매율[입고량대비]', '기간입고량',
#        '기간출고량', '소진율', '판매주차수', '매장명_y', '유통경로', '피팅룸수', '영업일수', '공급면적(평)',
#        '인원', '오픈일수', '서비스 캐파', '구포_매장진열캐파', '구미포_매장진열캐파', '구포_매장복잡도',
#        '구미포_매장복잡도'],
#       dtype='object')

# %%
dummy_df = pd.get_dummies(df_merge3['유통경로'], prefix='유통경로')
df_final = pd.concat([df_merge3, dummy_df], axis=1)

# %%
df_final.to_csv('regression_최종.csv', encoding='utf-8-sig')

# %%
sns.heatmap(df_final.corr(), annot=True, annot_kws={"size": 4}, cmap='coolwarm')
# Out:
# /var/folders/x2/c6gjhmqs6h5bl_d26ctv923h0000gn/T/ipykernel_30185/882087746.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_final.corr(), annot=True, annot_kws={"size": 4}, cmap='coolwarm')
# <AxesSubplot:>

# %%
df_cloth = pd.read_excel('/Users/yebinko/Library/Mobile Documents/com~apple~CloudDocs/Documents/BA/Capstone/마스터파일/스파오 상품 DATA(22년) (1).xlsx')
